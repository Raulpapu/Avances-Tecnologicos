# %% [markdown]
# 🏗️ Modelos de Servicio (Capas principales)
#
# 1. IaaS - Infraestructura como Servicio
#
# "Alquilas la infraestructura básica"
#
# Qué es: Servicios de infraestructura fundamental (servidores virtuales, almacenamiento, redes)
#
# Tú controlas: SO, aplicaciones, datos
#
# Proveedor controla: Hardware, virtualización
#
# Ejemplos: AWS EC2, Google Compute Engine, Azure Virtual Machines
#
# 2. PaaS - Plataforma como Servicio
#
# "Alquilas la plataforma de desarrollo"
#
# Qué es: Entorno para desarrollar, ejecutar y gestionar aplicaciones
#
# Tú controlas: Aplicaciones y datos
#
# Proveedor controla: SO, middleware, runtime
#
# Ejemplos: Google App Engine, Heroku, AWS Elastic Beanstalk
#
# 3. SaaS - Software como Servicio
#
# "Alquilas el software"
#
# Qué es: Software listo para usar a través de Internet
#
# Tú controlas: Configuración (limitada)
#
# Proveedor controla: Todo lo demás
#
# Ejemplos: Gmail, Office 365, Salesforce, Slack
#
# 🏢 Modelos de Implementación
#
# 1. Nube Pública
#
# Recursos compartidos entre múltiples organizaciones
#
# Propiedad: Proveedor externo (AWS, Azure, Google Cloud)
#
# Ventajas: Costos más bajos, sin mantenimiento, escalabilidad
#
# Ejemplo: Sitio web corporativo
#
# 2. Nube Privada
#
# Recursos exclusivos para una organización
#
# Propiedad: Puede ser interna o gestionada por terceros
#
# Ventajas: Mayor control y seguridad
#
# Ejemplo: Sistema bancario, datos médicos
#
# 3. Nube Híbrida
#
# Combinación de nubes públicas y privadas
#
# Permite mover datos y aplicaciones entre ambientes
#
# Ventajas: Flexibilidad, optimización de costos
#
# Ejemplo: App con datos sensibles en privada y frontend en pública
#
# 4. Multicloud
#
# Uso de múltiples proveedores de nube pública
#
# Evita dependencia de un solo proveedor
#
# Ventajas: Redundancia, mejores precios
#
# ⭐ Características Esenciales
#
# 1. Autoservicio bajo demanda
#
# Los usuarios pueden provisionar recursos sin intervención humana
#
# 2. Acceso amplio por red
#
# Acceso desde cualquier dispositivo con Internet
#
# 3. Agrupación de recursos (Resource Pooling)
#
# Recursos compartidos entre múltiples clientes (multi-tenant)
#
# 4. Elasticidad rápida
#
# Escalado automático según demanda
#
# 5. Servicio medido
#
# Pago solo por lo que se usa (como la electricidad)
#
# Ventajas y Consideraciones
#
# ✅ Ventajas
#
# Reducción de costos: No hay inversión en hardware
#
# Escalabilidad: Crece según necesidades
#
# Alta disponibilidad: 99.9%+ uptime
#
# Actualizaciones automáticas: Siempre la última tecnología
#
# Backup y recuperación: Más fácil y seguro
#
# ⚠️ Consideraciones
#
# Dependencia de Internet: Sin conexión, sin servicio
#
# Seguridad: Datos en servidores de terceros
#
# Costos ocultos: Pueden acumularse si no se monitoriza
#
# Vendor lock-in: Dificultad para cambiar de proveedor
#
# 🌐 Proveedores Principales
#
# AWS (Amazon Web Services): Líder del mercado
#
# Microsoft Azure: Fuerte integración con productos Microsoft
#
# Google Cloud Platform: Potente en AI/ML y analytics
#
# IBM Cloud: Foco en enterprise e IA
#
# Oracle Cloud: Especializado en bases de datos
#
# 🔄 Casos de Uso Comunes
#
# Almacenamiento y backup (Google Drive, Dropbox)
#
# Desarrollo de aplicaciones (Netflix, Airbnb)
#
# Análisis de big data
#
# Machine Learning e IA
#
# Sitios web y e-commerce
